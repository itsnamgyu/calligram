# %%
from data.glyph import GlyphLoader
import matplotlib.pyplot as plt

# %%
gl = GlyphLoader("/Users/itsnamgyu/code/calligram/input/glyph/hicau_mod0")

# %%
img = gl.load_glyph("찮", 0)
plt.imshow(img)

# %%
chars = ["과", "눠", "렁", "않"]
fig = plt.Figure(figsize=(10, 5))
axes = fig.subplots(1, len(chars))
for i, c in enumerate(chars):
    img = gl.load_glyph(c, 0)
    axes[i].imshow(img)
fig

# %%
fig = plt.Figure(figsize=(10, 5))
axes = fig.subplots(1, len(chars))
for i, c in enumerate(chars):
    img = gl.load_glyph(c, 8)
    axes[i].imshow(img)
fig
