# %%
from data.glyph import GlyphLoader
from generator.generator import generate_page_data
import matplotlib.pyplot as plt

# %%
gl = GlyphLoader("/Users/itsnamgyu/code/calligram/input/glyph/hicau_mod0")

# %%
img = gl.load_glyph("찮", 0)
fig = plt.Figure(figsize=(10, 5))
axes = fig.subplots(2, 5).flatten()
for i, ax in enumerate(axes):
    img = gl.load_glyph("찮", i)
    ax.imshow(img)
fig

# %%
def show_image(string, variant=0):
    fig = plt.Figure(figsize=(10, 10))
    ax = fig.subplots()
    image, text = generate_page_data(gl, string, variant, character_per_page=1000)
    ax.imshow(image)
    return fig
variant = 0

# %%
variant += 1
show_image("계절이 지나가는 하늘에는 가을로 가득 차 있습니다. 나는 아무 걱정도 없이 가을 속의 별들을 다 헬 듯합니다. 가슴 속에 하나 둘 새겨지는 별을 이제 다 못 헤는 것은 쉬이 아침이 오는 까닭이요, 내일 밤이 남은 까닭이요, 아직 나의 청춘이 다하지 않은 까닭입니다.", variant)
